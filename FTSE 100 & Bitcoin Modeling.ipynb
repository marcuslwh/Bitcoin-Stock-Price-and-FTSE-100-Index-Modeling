# %% [markdown]
# # FTSE 100 Index

# %%
library(astsa)
library(tseries)
library(forecast)
library(fGarch)
# Out:
# Registered S3 method overwritten by 'xts':
#   method     from
#   as.zoo.xts zoo
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# Registered S3 methods overwritten by 'forecast':
#   method             from
#   fitted.fracdiff    fracdiff
#   residuals.fracdiff fracdiff
#
# Attaching package: 'forecast'
#
# The following object is masked from 'package:astsa':
#
#     gas
#
# Loading required package: timeDate
# Loading required package: timeSeries
# Loading required package: fBasics
#
# Attaching package: 'fBasics'
#
# The following object is masked from 'package:astsa':
#
#     nyse

# %%
library(fGarch)

# %%
EuStockMarkets
# Out:
# ERROR while rich displaying an object: Error in repr_matrix_generic(obj, "\n%s%s\n", sprintf("|%%s\n|%s|\n", : formal argument "cols" matched by multiple actual arguments
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
# ...

# %%
FTSE=EuStockMarkets[,4]
plot(FTSE, main="FTSE in Levels")
# Out:
# Plot with title "FTSE in Levels"

# %%
dlogftse=log(FTSE)
plot(dlogftse, main="FTSE in Returns")
# Out:
# Plot with title "FTSE in Returns"

# %%
acf(dlogftse)
# Out:
# Plot with title "Series  dlogftse"

# %%
pacf(dlogftse)
# Out:
# Plot with title "Series  dlogftse"

# %%
adf.test(dlogftse)
# Out:
# 	Augmented Dickey-Fuller Test
#
# data:  dlogftse
# Dickey-Fuller = -2.4976, Lag order = 12, p-value = 0.3677
# alternative hypothesis: stationary

# %%
ftsemodel=auto.arima(dlogftse, ic="aic", trace=TRUE)
# Out:
#  Fitting models using approximations to speed things up...
#
#  ARIMA(2,1,2)(1,0,1)[260] with drift         : Inf
#  ARIMA(0,1,0)             with drift         : -12683.09
#  ARIMA(1,1,0)(1,0,0)[260] with drift         : Inf
#  ARIMA(0,1,1)(0,0,1)[260] with drift         : Inf
#  ARIMA(0,1,0)                                : -12679.62
#  ARIMA(0,1,0)(1,0,0)[260] with drift         : Inf
#  ARIMA(0,1,0)(0,0,1)[260] with drift         : Inf
#  ARIMA(0,1,0)(1,0,1)[260] with drift         : Inf
#  ARIMA(1,1,0)             with drift         : -12696.56
#  ARIMA(1,1,0)(0,0,1)[260] with drift         : Inf
#  ARIMA(1,1,0)(1,0,1)[260] with drift         : Inf
#  ARIMA(2,1,0)             with drift         : -12694.64
#  ARIMA(1,1,1)             with drift         : -12695.48
#  ARIMA(0,1,1)             with drift         : -12697.33
#  ARIMA(0,1,1)(1,0,0)[260] with drift         : Inf
#  ARIMA(0,1,1)(1,0,1)[260] with drift         : Inf
# ...

# %%
sarima(dlogftse,1,1,0)
# Out:
# initial  value -4.833783
# iter   2 value -4.838040
# iter   2 value -4.838040
# iter   2 value -4.838040
# final  value -4.838040
# converged
# initial  value -4.838136
# iter   1 value -4.838136
# final  value -4.838136
# converged
# $fit
#
# Call:
# stats::arima(x = xdata, order = c(p, d, q), seasonal = list(order = c(P, D,
#     Q), period = S), xreg = constant, transform.pars = trans, fixed = fixed,
#     optim.control = list(trace = trc, REPORT = 1, reltol = tol))
#
# Coefficients:
#          ar1  constant
#       0.0921     4e-04
# s.e.  0.0231     2e-04
#
# sigma^2 estimated as 6.275e-05:  log likelihood = 6356.29,  aic = -12706.58
#
# $degrees_of_freedom
# [1] 1857
#
# $ttable
#          Estimate     SE t.value p.value
# ar1        0.0921 0.0231  3.9865  0.0001
# constant   0.0004 0.0002  2.1190  0.0342
#
# $AIC
# [1] -6.835168
#
# $AICc
# [1] -6.835164
#
# $BIC
# [1] -6.826247
# Plot with title "p values for Ljung-Box statistic"

# %%
dlogftse2=(dlogftse)^2
plot(dlogftse2, main="Squared of FTSE Returns")
# Out:
# Plot with title "Squared of FTSE Returns"

# %%
resu=sarima(dlogftse,1,1,0)
resu2=(resid(resu$fit))^2
plot(resu2, main="Plot of Squared of Standardized Residuals")
# Out:
# initial  value -4.833783
# iter   2 value -4.838040
# iter   2 value -4.838040
# iter   2 value -4.838040
# final  value -4.838040
# converged
# initial  value -4.838136
# iter   1 value -4.838136
# final  value -4.838136
# converged
# Plot with title "p values for Ljung-Box statistic"
# Plot with title "Plot of Squared of Standardized Residuals"

# %%
acf(resu2)
# Out:
# Plot with title "Series  resu2"

# %%
pacf(resu2)
# Out:
# Plot with title "Series  resu2"

# %%
auto.arima(resu2, ic="aic", trace=TRUE)
# Out:
#  Fitting models using approximations to speed things up...
#
#  ARIMA(2,1,2)(1,0,1)[260] with drift         : Inf
#  ARIMA(0,1,0)             with drift         : -26829.61
#  ARIMA(1,1,0)(1,0,0)[260] with drift         : Inf
#  ARIMA(0,1,1)(0,0,1)[260] with drift         : Inf
#  ARIMA(0,1,0)                                : -26831.61
#  ARIMA(0,1,0)(1,0,0)[260] with drift         : -27280.02
#  ARIMA(0,1,0)(2,0,0)[260] with drift         : Inf
#  ARIMA(0,1,0)(1,0,1)[260] with drift         : Inf
#  ARIMA(0,1,0)(0,0,1)[260] with drift         : -26828.04
#  ARIMA(0,1,0)(2,0,1)[260] with drift         : Inf
#  ARIMA(0,1,1)(1,0,0)[260] with drift         : -28429.21
#  ARIMA(0,1,1)             with drift         : -27980.27
#  ARIMA(0,1,1)(2,0,0)[260] with drift         : Inf
#  ARIMA(0,1,1)(1,0,1)[260] with drift         : Inf
#  ARIMA(0,1,1)(2,0,1)[260] with drift         : Inf
#  ARIMA(1,1,1)(1,0,0)[260] with drift         : Inf
#  ARIMA(0,1,2)(1,0,0)[260] with drift         : Inf
# ...

# %%
summary(garchFit(~arma(1,0)+garch(1,1),dlogftse))
# Out:
# Series Initialization:
#  ARMA Model:                arma
#  Formula Mean:              ~ arma(1, 0)
#  GARCH Model:               garch
#  Formula Variance:          ~ garch(1, 1)
#  ARMA Order:                1 0
#  Max ARMA Order:            1
#  GARCH Order:               1 1
#  Max GARCH Order:           1
#  Maximum Order:             1
#  Conditional Dist:          norm
#  h.start:                   2
#  llh.start:                 1
#  Length of Series:          1860
#  Recursion Init:            mci
#  Series Scale:              0.2537956
#
# Parameter Initialization:
#  Initial Parameters:          $params
#  Limits of Transformations:   $U, $V
#  Which Parameters are Fixed?  $includes
#  Parameter Matrix:
#                        U        V     params includes
#     mu     -320.94178596 320.9418 32.0960565     TRUE
#     ar1      -0.99999999   1.0000  0.9997578     TRUE
#     omega     0.00000100 100.0000  0.1000000     TRUE
# ...

# %% [markdown]
# # Bitcoin

# %%
bc = read.csv('C:/Users/marcu/Desktop/Personal/Projects/Bitcoin Prices.csv')
bc
# Out:
#      Date       BITCOIN
# 1    1/2/2015   315.032
# 2    1/3/2015   281.082
# 3    1/4/2015   264.195
# 4    1/5/2015   274.474
# 5    1/6/2015   286.189
# 6    1/7/2015   294.337
# 7    1/8/2015   283.349
# 8    1/9/2015   290.408
# 9    1/10/2015  274.796
# 10   1/11/2015  265.660
# 11   1/12/2015  267.796
# 12   1/13/2015  225.861
# 13   1/14/2015  178.103
# 14   1/15/2015  209.844
# 15   1/16/2015  208.097
# 16   1/17/2015  199.260
# 17   1/18/2015  210.339
# 18   1/19/2015  214.861
# 19   1/20/2015  211.315
# 20   1/21/2015  226.897
# 21   1/22/2015  233.406
# 22   1/23/2015  232.879
# 23   1/24/2015  247.847
# 24   1/25/2015  253.718
# 25   1/26/2015  273.473
# 26   1/27/2015  263.475
# 27   1/28/2015  233.915
# 28   1/29/2015  233.513
# 29   1/30/2015  226.425
# 30   1/31/2015  217.464
# ...  ...        ...
# 1798 12/4/2019  7252.035
# 1799 12/5/2019  7448.308
# 1800 12/6/2019  7546.997
# 1801 12/7/2019  7556.238
# 1802 12/8/2019  7564.345
# 1803 12/9/2019  7400.899
# ...

# %%
btctime=ts(bc[,'BITCOIN'], frequency=12, start=c(2015,1))
plot(btctime, main="Bitcoin Price")
# Out:
# Plot with title "Bitcoin Price"

# %%
logbtctime=log(btctime)
plot(logbtctime, main="Bitcoin in Logs Price")
# Out:
# Plot with title "Bitcoin in Logs Price"

# %%
dlbc=diff(logbtctime,1)
plot(dlbc, main="Bitcoin in Returns")
# Out:
# Plot with title "Bitcoin in Returns"

# %%
adf.test(dlbc)
# Out:
# Warning message in adf.test(dlbc):
# "p-value smaller than printed p-value"
# 	Augmented Dickey-Fuller Test
#
# data:  dlbc
# Dickey-Fuller = -11.774, Lag order = 12, p-value = 0.01
# alternative hypothesis: stationary

# %%
acf(dlbc)
# Out:
# Plot with title "Series  dlbc"

# %%
pacf(dlbc)
# Out:
# Plot with title "Series  dlbc"

# %%
auto.arima(logbtctime, ic="aic", trace=TRUE)
# Out:
#  Fitting models using approximations to speed things up...
#
#  ARIMA(2,1,2)(1,0,1)[12] with drift         : -6753.062
#  ARIMA(0,1,0)            with drift         : -6669.231
#  ARIMA(1,1,0)(1,0,0)[12] with drift         : -6748.217
#  ARIMA(0,1,1)(0,0,1)[12] with drift         : -6665.239
#  ARIMA(0,1,0)                               : -6667.75
#  ARIMA(2,1,2)(0,0,1)[12] with drift         : -6670.364
#  ARIMA(2,1,2)(1,0,0)[12] with drift         : -6746.956
#  ARIMA(2,1,2)(2,0,1)[12] with drift         : -6753.487
#  ARIMA(2,1,2)(2,0,0)[12] with drift         : -6755.479
#  ARIMA(1,1,2)(2,0,0)[12] with drift         : -6753.403
#  ARIMA(2,1,1)(2,0,0)[12] with drift         : -6756.909
#  ARIMA(2,1,1)(1,0,0)[12] with drift         : -6743.317
#  ARIMA(2,1,1)(2,0,1)[12] with drift         : -6754.907
#  ARIMA(2,1,1)(1,0,1)[12] with drift         : -6744.563
#  ARIMA(1,1,1)(2,0,0)[12] with drift         : -6754.946
#  ARIMA(2,1,0)(2,0,0)[12] with drift         : -6758.908
# ...

# %%
sarima(logbtctime,0,1,0)
# Out:
# initial  value -3.247998
# iter   1 value -3.247998
# final  value -3.247998
# converged
# initial  value -3.247998
# iter   1 value -3.247998
# final  value -3.247998
# converged
# $fit
#
# Call:
# stats::arima(x = xdata, order = c(p, d, q), seasonal = list(order = c(P, D,
#     Q), period = S), xreg = constant, transform.pars = trans, fixed = fixed,
#     optim.control = list(trace = trc, REPORT = 1, reltol = tol))
#
# Coefficients:
#       constant
#         0.0017
# s.e.    0.0009
#
# sigma^2 estimated as 0.001509:  log likelihood = 3339.86,  aic = -6675.73
#
# $degrees_of_freedom
# [1] 1825
#
# $ttable
#          Estimate    SE t.value p.value
# constant   0.0017 9e-04   1.866  0.0622
#
# $AIC
# [1] -3.655928
#
# $AICc
# [1] -3.655927
#
# $BIC
# [1] -3.649894
# Plot with title "p values for Ljung-Box statistic"

# %%
dlbc2=(dlbc)^2
plot(dlbc2, main="Squared of Bitcoin")
# Out:
# Plot with title "Squared of Bitcoin"

# %%
resu=sarima(dlbc,0,0,0)
resu2=(resid(resu$fit))^2
plot(resu2, main="Plot of Squared of Standardized Residuals")
# Out:
# initial  value -3.247998
# iter   1 value -3.247998
# final  value -3.247998
# converged
# initial  value -3.247998
# iter   1 value -3.247998
# final  value -3.247998
# converged
# Plot with title "p values for Ljung-Box statistic"
# Plot with title "Plot of Squared of Standardized Residuals"

# %%
acf(resu2)
# Out:
# Plot with title "Series  resu2"

# %%
pacf(resu2)
# Out:
# Plot with title "Series  resu2"

# %%
auto.arima(resu2, ic="aic", trace=TRUE)
# Out:
#  Fitting models using approximations to speed things up...
#
#  ARIMA(2,1,2)(1,0,1)[12] with drift         : -15291.06
#  ARIMA(0,1,0)            with drift         : -14196.81
#  ARIMA(1,1,0)(1,0,0)[12] with drift         : -14707.58
#  ARIMA(0,1,1)(0,0,1)[12] with drift         : -14961.99
#  ARIMA(0,1,0)                               : -14198.81
#  ARIMA(2,1,2)(0,0,1)[12] with drift         : -15045.94
#  ARIMA(2,1,2)(1,0,0)[12] with drift         : -15292.84
#  ARIMA(2,1,2)            with drift         : -15047.83
#  ARIMA(2,1,2)(2,0,0)[12] with drift         : -15296.52
#  ARIMA(2,1,2)(2,0,1)[12] with drift         : -15294.52
#  ARIMA(1,1,2)(2,0,0)[12] with drift         : -15246.08
#  ARIMA(2,1,1)(2,0,0)[12] with drift         : -15289.87
#  ARIMA(3,1,2)(2,0,0)[12] with drift         : -15294.3
#  ARIMA(2,1,3)(2,0,0)[12] with drift         : -15294.35
#  ARIMA(1,1,1)(2,0,0)[12] with drift         : -15206.37
#  ARIMA(1,1,3)(2,0,0)[12] with drift         : -15257.98
# ...

# %%
summary(garchFit(~arma(0,0)+garch(1,2),dlbc))
# Out:
# Series Initialization:
#  ARMA Model:                arma
#  Formula Mean:              ~ arma(0, 0)
#  GARCH Model:               garch
#  Formula Variance:          ~ garch(1, 2)
#  ARMA Order:                0 0
#  Max ARMA Order:            0
#  GARCH Order:               1 2
#  Max GARCH Order:           2
#  Maximum Order:             2
#  Conditional Dist:          norm
#  h.start:                   3
#  llh.start:                 1
#  Length of Series:          1826
#  Recursion Init:            mci
#  Series Scale:              0.03886255
#
# Parameter Initialization:
#  Initial Parameters:          $params
#  Limits of Transformations:   $U, $V
#  Which Parameters are Fixed?  $includes
#  Parameter Matrix:
#                      U           V     params includes
#     mu     -0.43669411   0.4366941 0.04366941     TRUE
#     omega   0.00000100 100.0000000 0.10000000     TRUE
#     alpha1  0.00000001   1.0000000 0.10000000     TRUE
# ...
